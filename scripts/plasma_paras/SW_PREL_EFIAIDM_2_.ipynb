# %%
import pandas as pd
from pathlib import Path

# %%
script_dir = Path.cwd()
data_dir = script_dir / ".." / ".." / "data"
file_name = "SW_PREL_EFIAIDM_2__12885_20160311T061733_20160311T075106.pkl"
file_path = data_dir / file_name

# %%
df = pd.read_pickle(file_path)

# %%
df['N_i_Flags'].plot()
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df['N_i'].plot()
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df['M_i_eff'].plot()
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df['M_i_eff_err'].plot()
# Out:
# <Axes: xlabel='Timestamp'>

# %%
import matplotlib.pyplot as plt
plt.plot(df['M_i_eff_err'])
plt.yscale('log')
