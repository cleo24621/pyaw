# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
script_dir = Path.cwd()
data_dir = script_dir / ".." / ".." / "data"
file_name = "SW_OPER_EFIA_LP_1B_12885_20160311T061733_20160311T075106.pkl"
file_path = data_dir / file_name

# %%
df = pd.read_pickle(file_path)

# %%
flags_te_value_counts = df["Flags_Te"].value_counts()
flags_te_value_counts
# Out:
# Flags_Te
# 10    6885
# 12    3619
# 20     358
# 22     305
# 19      35
# 40      12
# 32       7
# 36       5
# Name: count, dtype: int64

# %%
flags_lp_value_counts = df["Flags_LP"].value_counts()
flags_lp_value_counts
# Out:
# Flags_LP
# 1    10601
# 3      537
# 9       88
# Name: count, dtype: int64

# %%
flags_te_value_counts = df["Flags_Te"].value_counts()
flags_te_value_counts
# Out:
# Flags_Te
# 10    6885
# 12    3619
# 20     358
# 22     305
# 19      35
# 40      12
# 32       7
# 36       5
# Name: count, dtype: int64

# %%
df["Ne"].plot()
# Out:
# <Axes: xlabel='Timestamp'>

# %%
df["Te"].plot()
# Out:
# <Axes: xlabel='Timestamp'>
